# %%
from manim import *

config.media_width = "55%"
config.verbosity = "WARNING"
# Out:
# Manim Community v0.15.1

# %%
# %%manim -qm Scene010
#
# class Scene010(Scene):
#     def construct(self):
#
#         ax = Axes()
#
#         self.add(ax)
